# %%
# Dependencies
import numpy as np
import datetime as dt
import pandas as pd
#add the specific style we want, fivethirtyeight
from matplotlib import style
style.use('fivethirtyeight')
#plotting framework
import matplotlib.pyplot as plt

# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
engine = create_engine("sqlite:///hawaii.sqlite")

# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

#references the classes that were mapped in each table.
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %% [markdown]
# ## D1: Determine the Summary Statistics for June

# %%
# 1. Import the sqlalchemy extract function.
from sqlalchemy import extract

# 2. Write a query that filters the Measurement table to retrieve the temperatures for the month of June. 
#resource: https://stackoverflow.com/questions/12019766/how-to-get-month-and-year-from-date-field-in-sqlalchemy
temp_june=session.query(Measurement.date, Measurement.tobs).filter(extract('month', Measurement.date) == 6).all()

# %%
#  3. Convert the June temperatures to a list.
print(temp_june)
# Out:
# [('2010-06-01', 78.0), ('2010-06-02', 76.0), ('2010-06-03', 78.0), ('2010-06-04', 76.0), ('2010-06-05', 77.0), ('2010-06-06', 78.0), ('2010-06-07', 77.0), ('2010-06-08', 78.0), ('2010-06-09', 78.0), ('2010-06-10', 79.0), ('2010-06-11', 78.0), ('2010-06-12', 78.0), ('2010-06-13', 78.0), ('2010-06-14', 77.0), ('2010-06-15', 78.0), ('2010-06-16', 78.0), ('2010-06-17', 77.0), ('2010-06-18', 77.0), ('2010-06-19', 82.0), ('2010-06-20', 78.0), ('2010-06-21', 78.0), ('2010-06-22', 78.0), ('2010-06-23', 78.0), ('2010-06-24', 78.0), ('2010-06-25', 77.0), ('2010-06-26', 76.0), ('2010-06-27', 78.0), ('2010-06-28', 78.0), ('2010-06-29', 78.0), ('2010-06-30', 78.0), ('2011-06-01', 77.0), ('2011-06-02', 78.0), ('2011-06-03', 73.0), ('2011-06-04', 70.0), ('2011-06-05', 76.0), ('2011-06-06', 77.0), ('2011-06-07', 77.0), ('2011-06-08', 77.0), ('2011-06-09', 77.0), ('2011-06-10', 78.0), ('2011-06-11', 77.0), ('2011-06-12', 77.0), ('2011-06-13', 78.0), ('2011-06-14', 78.0), ('2011-06-15', 77.0), ('2011-
# ...

# %%
# 4. Create a DataFrame from the list of temperatures for the month of June. 
temp_june_df=pd.DataFrame(temp_june, columns=['date', 'temperature'])
temp_june_df.head(3)
# Out:
#          date  temperature
# 0  2010-06-01         78.0
# 1  2010-06-02         76.0
# 2  2010-06-03         78.0

# %%
temp_june_df.set_index(temp_june_df['date'], inplace=True)
temp_june_df.to_string(index=False)
temp_june_df = temp_june_df.sort_index()
temp_june_df.to_string(index=False)

temp_june_df.plot.hist(bins=20)
plt.title('June Temperature Observations')
plt.tight_layout()

# %%
# 5. Calculate and print out the summary statistics for the June temperature DataFrame.
temp_june_df.describe()
# Out:
#        temperature
# count  1700.000000
# mean     74.944118
# std       3.257417
# min      64.000000
# 25%      73.000000
# 50%      75.000000
# 75%      77.000000
# max      85.000000

# %%
# Additional query that filters the precipitation table to retrieve the temperatures for the month of June. 
prcp_june=session.query(Measurement.date, Measurement.prcp).filter(extract('month', Measurement.date) == 6).all()

# %%
print(prcp_june)
# Out:
# [('2010-06-01', 0.0), ('2010-06-02', 0.01), ('2010-06-03', 0.0), ('2010-06-04', 0.0), ('2010-06-05', 0.0), ('2010-06-06', 0.0), ('2010-06-07', 0.0), ('2010-06-08', 0.0), ('2010-06-09', 0.0), ('2010-06-10', 0.0), ('2010-06-11', 0.0), ('2010-06-12', 0.0), ('2010-06-13', 0.0), ('2010-06-14', 0.0), ('2010-06-15', 0.0), ('2010-06-16', 0.0), ('2010-06-17', 0.0), ('2010-06-18', 0.0), ('2010-06-19', 0.0), ('2010-06-20', 0.0), ('2010-06-21', 0.0), ('2010-06-22', 0.0), ('2010-06-23', 0.0), ('2010-06-24', 0.0), ('2010-06-25', 0.0), ('2010-06-26', 0.02), ('2010-06-27', 0.0), ('2010-06-28', 0.0), ('2010-06-29', 0.0), ('2010-06-30', 0.0), ('2011-06-01', 0.07), ('2011-06-02', 0.0), ('2011-06-03', 0.56), ('2011-06-04', 0.89), ('2011-06-05', 0.0), ('2011-06-06', 0.0), ('2011-06-07', 0.0), ('2011-06-08', 0.03), ('2011-06-09', 0.01), ('2011-06-10', 0.0), ('2011-06-11', 0.0), ('2011-06-12', 0.0), ('2011-06-13', 0.0), ('2011-06-14', 0.0), ('2011-06-15', 0.0), ('2011-06-17', 0.0), ('2011-06-18', 0.0), ('2
# ...

# %%
prcp_june_df=pd.DataFrame(prcp_june, columns=['date', 'precipitation'])
prcp_june_df.head(3)
# Out:
#          date  precipitation
# 0  2010-06-01           0.00
# 1  2010-06-02           0.01
# 2  2010-06-03           0.00

# %%
prcp_june_df.set_index(prcp_june_df['date'], inplace=True)
prcp_june_df.to_string(index=False)
prcp_june_df = prcp_june_df.sort_index()
prcp_june_df.to_string(index=False)

prcp_june_df.plot()
plt.title('June Precipitation Observations')
plt.locator_params(nbins=5)
plt.show()

# %%
prcp_june_df.describe()
# Out:
#        precipitation
# count    1574.000000
# mean        0.136360
# std         0.335731
# min         0.000000
# 25%         0.000000
# 50%         0.020000
# 75%         0.120000
# max         4.430000

# %% [markdown]
# ## D2: Determine the Summary Statistics for December

# %%
# 6. Write a query that filters the Measurement table to retrieve the temperatures for the month of December.
#resource: https://stackoverflow.com/questions/12019766/how-to-get-month-and-year-from-date-field-in-sqlalchemy
temp_dec=session.query(Measurement.date, Measurement.tobs).filter(extract('month', Measurement.date) == 12).all()

# %%
# 7. Convert the December temperatures to a list.
print(temp_dec)
# Out:
# [('2010-12-01', 76.0), ('2010-12-03', 74.0), ('2010-12-04', 74.0), ('2010-12-06', 64.0), ('2010-12-07', 64.0), ('2010-12-08', 67.0), ('2010-12-09', 77.0), ('2010-12-10', 66.0), ('2010-12-11', 69.0), ('2010-12-12', 68.0), ('2010-12-13', 68.0), ('2010-12-14', 71.0), ('2010-12-15', 74.0), ('2010-12-16', 67.0), ('2010-12-17', 66.0), ('2010-12-18', 69.0), ('2010-12-19', 71.0), ('2010-12-23', 70.0), ('2010-12-24', 70.0), ('2010-12-26', 74.0), ('2010-12-27', 74.0), ('2010-12-28', 71.0), ('2010-12-29', 75.0), ('2010-12-30', 75.0), ('2010-12-31', 72.0), ('2011-12-01', 69.0), ('2011-12-02', 68.0), ('2011-12-03', 73.0), ('2011-12-04', 74.0), ('2011-12-05', 73.0), ('2011-12-06', 73.0), ('2011-12-07', 73.0), ('2011-12-08', 73.0), ('2011-12-09', 71.0), ('2011-12-10', 73.0), ('2011-12-11', 73.0), ('2011-12-12', 77.0), ('2011-12-13', 72.0), ('2011-12-14', 71.0), ('2011-12-15', 73.0), ('2011-12-16', 70.0), ('2011-12-17', 73.0), ('2011-12-18', 69.0), ('2011-12-19', 74.0), ('2011-12-20', 72.0), ('2011-
# ...

# %%
# 8. Create a DataFrame from the list of temperatures for the month of December. 
temp_dec_df=pd.DataFrame(temp_dec, columns=['date', 'temperature'])
temp_dec_df.head(3)
# Out:
#          date  temperature
# 0  2010-12-01         76.0
# 1  2010-12-03         74.0
# 2  2010-12-04         74.0

# %%
temp_dec_df.set_index(temp_dec_df['date'], inplace=True)
temp_dec_df.to_string(index=False)
temp_dec_df = temp_dec_df.sort_index()
temp_dec_df.to_string(index=False)

temp_dec_df.plot.hist(bins=20)
plt.title('December Temperature Observations')
plt.tight_layout()

# %%
# 9. Calculate and print out the summary statistics for the Decemeber temperature DataFrame.
temp_dec_df.describe()
# Out:
#        temperature
# count  1517.000000
# mean     71.041529
# std       3.745920
# min      56.000000
# 25%      69.000000
# 50%      71.000000
# 75%      74.000000
# max      83.000000

# %%
# Additional query that filters the precipitation table to retrieve the temperatures for the month of June. 
prcp_dec=session.query(Measurement.date, Measurement.prcp).filter(extract('month', Measurement.date) == 12).all()

# %%
print(prcp_dec)
# Out:
# [('2010-12-01', 0.04), ('2010-12-03', 0.0), ('2010-12-04', 0.0), ('2010-12-06', 0.0), ('2010-12-07', 0.0), ('2010-12-08', 0.0), ('2010-12-09', 0.0), ('2010-12-10', 1.58), ('2010-12-11', 0.77), ('2010-12-12', 0.0), ('2010-12-13', 0.0), ('2010-12-14', 0.0), ('2010-12-15', 0.0), ('2010-12-16', 0.0), ('2010-12-17', 0.0), ('2010-12-18', 0.0), ('2010-12-19', 1.4), ('2010-12-23', 0.0), ('2010-12-24', 0.0), ('2010-12-26', None), ('2010-12-27', 0.13), ('2010-12-28', 0.55), ('2010-12-29', 0.06), ('2010-12-30', 0.01), ('2010-12-31', 0.0), ('2011-12-01', 0.03), ('2011-12-02', 0.08), ('2011-12-03', 0.0), ('2011-12-04', 0.0), ('2011-12-05', 0.0), ('2011-12-06', 0.0), ('2011-12-07', 0.0), ('2011-12-08', 0.0), ('2011-12-09', 0.13), ('2011-12-10', 0.07), ('2011-12-11', 0.07), ('2011-12-12', 0.08), ('2011-12-13', 0.4), ('2011-12-14', 0.7), ('2011-12-15', 0.0), ('2011-12-16', 0.01), ('2011-12-17', 0.07), ('2011-12-18', 0.02), ('2011-12-19', 0.15), ('2011-12-20', 0.02), ('2011-12-21', 0.18), ('2011-12-2
# ...

# %%
prcp_dec_df=pd.DataFrame(prcp_dec, columns=['date', 'precipitation'])
prcp_dec_df.head(3)
# Out:
#          date  precipitation
# 0  2010-12-01           0.04
# 1  2010-12-03           0.00
# 2  2010-12-04           0.00

# %%
prcp_dec_df.set_index(prcp_dec_df['date'], inplace=True)
prcp_dec_df.to_string(index=False)
prcp_dec_df = prcp_dec_df.sort_index()
prcp_dec_df.to_string(index=False)

prcp_dec_df.plot()
plt.title('December Precipitation Observations')
plt.locator_params(nbins=6)
plt.show()

# %%
prcp_dec_df.describe()
# Out:
#        precipitation
# count    1405.000000
# mean        0.216819
# std         0.541399
# min         0.000000
# 25%         0.000000
# 50%         0.030000
# 75%         0.150000
# max         6.420000

# %%
session.query(func.count(Station.station)).all()
# Out:
# [(9,)]

# %%
#determine the most active stations, group it and order it by desc
session.query(Measurement.station, func.count(Measurement.station)).\
group_by(Measurement.station).order_by(func.count(Measurement.station).desc()).all()
# Out:
# [('USC00519281', 2772),
#  ('USC00519397', 2724),
#  ('USC00513117', 2709),
#  ('USC00519523', 2669),
#  ('USC00516128', 2612),
#  ('USC00514830', 2202),
#  ('USC00511918', 1979),
#  ('USC00517948', 1372),
#  ('USC00518838', 511)]

# %%
#calculate the minimum, maximum, and average temperatures for the most active station
session.query(func.min(Measurement.tobs), func.max(Measurement.tobs), func.avg(Measurement.tobs)).\
filter(Measurement.station == 'USC00519281').all()
# Out:
# [(54.0, 85.0, 71.66378066378067)]

# %%
station_june = session.query(Measurement.date, Measurement.tobs).\
filter(Measurement.station == 'USC00519281').\
filter(extract('month', Measurement.date) == 6).all()
station_june
# Out:
# [('2010-06-01', 71.0),
#  ('2010-06-02', 71.0),
#  ('2010-06-03', 72.0),
#  ('2010-06-04', 72.0),
#  ('2010-06-05', 76.0),
#  ('2010-06-06', 77.0),
#  ('2010-06-07', 71.0),
#  ('2010-06-08', 73.0),
#  ('2010-06-09', 73.0),
#  ('2010-06-10', 75.0),
#  ('2010-06-11', 81.0),
#  ('2010-06-12', 74.0),
#  ('2010-06-13', 77.0),
#  ('2010-06-14', 70.0),
#  ('2010-06-15', 69.0),
#  ('2010-06-16', 70.0),
#  ('2010-06-17', 72.0),
#  ('2010-06-18', 71.0),
#  ('2010-06-19', 77.0),
#  ('2010-06-20', 76.0),
#  ('2010-06-21', 74.0),
#  ('2010-06-22', 74.0),
#  ('2010-06-23', 74.0),
#  ('2010-06-24', 74.0),
#  ('2010-06-25', 71.0),
#  ('2010-06-26', 80.0),
#  ('2010-06-27', 77.0),
#  ('2010-06-28', 72.0),
#  ('2010-06-29', 72.0),
#  ('2010-06-30', 73.0),
#  ('2011-06-01', 72.0),
#  ('2011-06-02', 73.0),
#  ('2011-06-03', 73.0),
#  ('2011-06-08', 77.0),
#  ('2011-06-09', 76.0),
#  ('2011-06-10', 79.0),
#  ('2011-06-11', 78.0),
#  ('2011-06-12', 82.0),
#  ('2011-06-13', 79.0),
#  ('2011-06-14', 76.0),
# ...

# %%
station_june_df=pd.DataFrame(station_june, columns=['date', 'temperature'])
station_june_df
# Out:
#            date  temperature
# 0    2010-06-01         71.0
# 1    2010-06-02         71.0
# 2    2010-06-03         72.0
# 3    2010-06-04         72.0
# 4    2010-06-05         76.0
# ..          ...          ...
# 231  2017-06-26         73.0
# 232  2017-06-27         76.0
# 233  2017-06-28         77.0
# 234  2017-06-29         76.0
# 235  2017-06-30         76.0
#
# [236 rows x 2 columns]

# %%
station_june_df.set_index(station_june_df['date'], inplace=True)
station_june_df.to_string(index=False)
station_june_df = station_june_df.sort_index()
station_june_df.to_string(index=False)

station_june_df.plot.hist(bins=20)
plt.title('June Temperature Observations (Most Active Station)')
plt.tight_layout()

# %%
station_dec = session.query(Measurement.date, Measurement.tobs).\
filter(Measurement.station == 'USC00519281').\
filter(extract('month', Measurement.date) == 12).all()
station_dec
# Out:
# [('2010-12-01', 72.0),
#  ('2010-12-02', 71.0),
#  ('2010-12-03', 72.0),
#  ('2010-12-04', 74.0),
#  ('2010-12-05', 66.0),
#  ('2010-12-06', 61.0),
#  ('2010-12-07', 58.0),
#  ('2010-12-08', 60.0),
#  ('2010-12-09', 71.0),
#  ('2010-12-10', 65.0),
#  ('2010-12-11', 72.0),
#  ('2010-12-12', 70.0),
#  ('2010-12-13', 68.0),
#  ('2010-12-14', 67.0),
#  ('2010-12-15', 71.0),
#  ('2010-12-16', 65.0),
#  ('2010-12-17', 64.0),
#  ('2010-12-18', 65.0),
#  ('2010-12-19', 69.0),
#  ('2010-12-20', 70.0),
#  ('2010-12-21', 70.0),
#  ('2010-12-22', 68.0),
#  ('2010-12-23', 69.0),
#  ('2010-12-24', 71.0),
#  ('2010-12-25', 70.0),
#  ('2010-12-26', 71.0),
#  ('2010-12-27', 76.0),
#  ('2010-12-28', 71.0),
#  ('2010-12-29', 72.0),
#  ('2010-12-30', 73.0),
#  ('2010-12-31', 77.0),
#  ('2011-12-01', 67.0),
#  ('2011-12-02', 69.0),
#  ('2011-12-03', 72.0),
#  ('2011-12-04', 74.0),
#  ('2011-12-05', 71.0),
#  ('2011-12-06', 70.0),
#  ('2011-12-07', 68.0),
#  ('2011-12-08', 70.0),
#  ('2011-12-09', 66.0),
# ...

# %%
station_dec_df=pd.DataFrame(station_dec, columns=['date', 'temperature'])
station_dec_df
# Out:
#            date  temperature
# 0    2010-12-01         72.0
# 1    2010-12-02         71.0
# 2    2010-12-03         72.0
# 3    2010-12-04         74.0
# 4    2010-12-05         66.0
# ..          ...          ...
# 212  2016-12-27         71.0
# 213  2016-12-28         72.0
# 214  2016-12-29         74.0
# 215  2016-12-30         69.0
# 216  2016-12-31         67.0
#
# [217 rows x 2 columns]

# %%
station_dec_df.set_index(station_dec_df['date'], inplace=True)
station_dec_df.to_string(index=False)
station_dec_df = station_dec_df.sort_index()
station_dec_df.to_string(index=False)

station_dec_df.plot.hist(bins=20)
plt.title('December Temperature Observations (Most Active Station)')
plt.tight_layout()
